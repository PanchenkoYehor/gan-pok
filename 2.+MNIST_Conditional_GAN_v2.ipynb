# %% [markdown]
# ### CGAN  on MNIST
#
# DCGAN is a Generative Adversarial Network (GAN) using CNN.
#
# 1. The discriminator learns to discriminate real from fake images.
# 2. The generator tries to fool the discriminator by generating fake images.
# 3. The generator + discriminator form an adversarial network.
# 4. DCGAN trains the discriminator and adversarial networks alternately.
#
# During training, not only the discriminator learns to distinguish real from
# fake images, it also coaches the generator part of the Adversarial network on how
# to improve its ability to generate fake images.

# %%
import tensorflow as tf

import numpy as np
import math
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### Buiding a Generator Model
#
# Build a model using layers of BatchNorm-ReLU-Conv2DTranpose to generate fake images

# %%
def build_generator(noise_inputs, label_inputs, image_size=28):
            
    #Concatenate both noise and labels
    x = tf.keras.layers.concatenate([noise_inputs, label_inputs], axis=1)
    
    #Increase dimensions and resize to 3D to feed it to Conv2DTranspose layer
    x = tf.keras.layers.Dense(7 * 7 * 128)(x)
    x = tf.keras.layers.Reshape((7, 7,128))(x)
    
    #Use ConvTranspose
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2DTranspose(128, kernel_size=[5,5], strides=2, padding='same')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2DTranspose(64, kernel_size=[5,5], strides=2, padding='same')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2DTranspose(32, kernel_size=[5,5], strides=1, padding='same')(x)
    
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2DTranspose(1, kernel_size=[5,5], strides=1, padding='same')(x)
    
    #Output layer for Generator
    x = tf.keras.layers.Activation('sigmoid')(x)
    
    generator = tf.keras.models.Model([noise_inputs, label_inputs], x, name='generator')
    
    return generator

# %% [markdown]
# #### Building a Discriminator

# %%
def build_discriminator(image_inputs, label_inputs, image_size=28):
    
    #Network parameters
    filter_size = 5
    num_filters = [32, 64, 128, 256]
    stride_size = [2, 2, 2, 1]
    
    #Build the network
    x = image_inputs
    
    #Make label_inputs of same size as image_inputs for concatenation
    y = tf.keras.layers.Dense(28*28)(label_inputs)
    y = tf.keras.layers.Reshape((28,28,1))(y)
    x = tf.keras.layers.concatenate([x, y])
    
    
    x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
    x = tf.keras.layers.Conv2D(32, kernel_size=[5,5], strides=2, padding='same')(x)
    
    x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
    x = tf.keras.layers.Conv2D(64, kernel_size=[5,5], strides=2, padding='same')(x)
    
    x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
    x = tf.keras.layers.Conv2D(128, kernel_size=[5,5], strides=2, padding='same')(x)
    
    x = tf.keras.layers.LeakyReLU(alpha=0.2)(x)
    x = tf.keras.layers.Conv2D(256, kernel_size=[5,5], strides=1, padding='same')(x)
    
    #Flatten the output and build an output layer
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    #Build Model
    discriminator = tf.keras.models.Model([image_inputs, label_inputs],
                                          x, name='discriminator')
    
    return discriminator

# %% [markdown]
# #### Building Models for Training

# %%
def build_models():
    
    noise_size = 100
    lr = 2e-4
    decay = 6e-8
    
    #Build input layers
    noise_inputs = tf.keras.layers.Input(shape=(noise_size,))
    label_inputs = tf.keras.layers.Input(shape=(10,))
    image_inputs = tf.keras.layers.Input(shape=(28, 28, 1,))
    
    #Build Base Discriminator model    
    base_discriminator = build_discriminator(image_inputs, label_inputs)
    
    #Define discriminator, optimizer and compile model
    discriminator = tf.keras.models.Model(inputs=base_discriminator.inputs, 
                                          outputs=base_discriminator.outputs)
    optimizer = tf.keras.optimizers.RMSprop(lr=lr, decay=decay)
    discriminator.compile(loss='binary_crossentropy',
                          optimizer=optimizer,
                          metrics=['accuracy'])
    
    #Build Generator model
    generator = build_generator(noise_inputs, label_inputs)
    
    #Build Frozen Discriminator
    frozen_discriminator = tf.keras.models.Model(inputs=base_discriminator.inputs, 
                                          outputs=base_discriminator.outputs)
    #Freeze the weights of discriminator during adversarial training
    frozen_discriminator.trainable = False

    #Build Adversarial model
    optimizer = tf.keras.optimizers.RMSprop(lr=lr * 0.5, decay=decay * 0.5)
        
    #Adversarial = generator + discriminator
    adversarial = tf.keras.models.Model([noise_inputs, label_inputs],
                                        frozen_discriminator([generator([noise_inputs, label_inputs]), label_inputs]))
    
    adversarial.compile(loss='binary_crossentropy',
                        optimizer=optimizer,
                        metrics=['accuracy'])    
    
    return generator, discriminator, adversarial

# %% [markdown]
# #### Training Discriminator and Adversarial Models

# %%
def train_gan(generator, discriminator, adversarial, noise_size=100):
    
    #Training parameters
    batch_size = 64
    train_steps = 10000
    image_size = 28
    num_labels = 10
    
    # load MNIST dataset
    (train_x, train_y), (_, _) = tf.keras.datasets.mnist.load_data()
    #Make it 3D dataset
    train_x = np.reshape(train_x, [-1, image_size, image_size, 1])
    #Standardize data : 0 to 1
    train_x = train_x.astype('float32') / 255
    
    #Convert labels to one-hot encoding
    train_y = tf.keras.utils.to_categorical(train_y)
    
    #Input for testing generator at different intervals, we will generate 16 images
    test_noise_input = np.random.uniform(-1.0,1.0, size=[16, noise_size])
    test_fake_labels = np.eye(num_labels)[np.random.choice(num_labels, 16)]
    
    #Start training
    for i in range(train_steps):
        
        #Train DISCRIMATOR
        
        #1. Get fake images from Generator
        noise_input = np.random.uniform(-1.0,1.0, size=[batch_size, noise_size])
        fake_labels = np.eye(num_labels)[np.random.choice(num_labels, batch_size)]
        fake_images = generator.predict([noise_input, fake_labels])
        
        
        #2. Get real images and labels from training set
        img_indexes = np.random.randint(0, train_x.shape[0], size=batch_size)
        real_images = train_x[img_indexes]
        real_labels = train_y[img_indexes]
        
        #3. Prepare input for training Discriminator
        X_images = np.concatenate((real_images, fake_images))
        X_labels = np.concatenate((real_labels, fake_labels))
        
        #4. Labels for training
        y_real = np.ones((batch_size, 1))
        y_fake = np.zeros((batch_size, 1))
        y = np.concatenate((y_real, y_fake))
        
        #5. Train Discriminator
        d_loss, d_acc = discriminator.train_on_batch([X_images, X_labels], y)
        
        
        #Train ADVERSARIAL Network
        
        #1. Prepare input - create a new batch of noise
        X_noise = np.random.uniform(-1.0,1.0, size=[batch_size, noise_size])
        X_fake_labels = np.eye(num_labels)[np.random.choice(num_labels, batch_size)]
        
        #2. Prepare labels - training Adversarial network to lie :) - All 1s
        y = np.ones((batch_size, 1))
        
        #3. Train - Pls note Discrimator is not getting trained here
        a_loss, a_acc = adversarial.train_on_batch([X_noise, X_fake_labels], y)
        
        if i % 100 == 0:
            #Print loss and Accuracy for both networks
            print("%s [Discriminator loss: %f, acc: %f, Adversarial loss: %f, acc: %f]" % (i, d_loss, d_acc, a_loss, a_acc) )
        
        #Save generated images to see how well Generator is doing
        if (i+1) % 500 == 0:
            
            #Generate 16 images
            fake_images = generator.predict([test_noise_input, test_fake_labels])
            
            #Display images
            plot_images(fake_images, i+1)
            
    #Save Generator model
    generator.save('mnist_generator_cgan.h5')

# %% [markdown]
# #### Save generator images

# %%
def plot_images(fake_images, step):
    
    plt.figure(figsize=(2.2, 2.2))
    num_images = fake_images.shape[0]
    
    image_size = fake_images.shape[1]
    rows = int(math.sqrt(fake_images.shape[0]))
    
    for i in range(num_images):
        plt.subplot(rows, rows, i + 1)
        image = np.reshape(fake_images[i], [image_size, image_size])
        plt.imshow(image, cmap='gray')
        plt.axis('off')
    plt.show()

# %% [markdown]
# ### Start GAN Training

# %%
G, D, A = build_models()
# Out:
# C:\Users\p84229100\Anaconda3\envs\kedro_env\lib\site-packages\keras\optimizers\optimizer_v2\rmsprop.py:140: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
G.summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  concatenate_1 (Concatenate)    (None, 110)          0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_2 (Dense)                (None, 6272)         696192      ['concatenate_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 7, 7, 128)    0           ['dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 7, 128)   512         ['reshape_1[0][0]']
#  alization)
#
#  activation (Activation)        (None, 7, 7, 128)    0           ['batch_normalization[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 128)  409728     ['activation[0][0]']
#  ose)
#
#  batch_normalization_1 (BatchNo  (None, 14, 14, 128)  512        ['conv2d_transpose[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 14, 14, 128)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 28, 28, 64)  204864      ['activation_1[0][0]']
#  spose)
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 64)  256         ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 28, 28, 32)  51232       ['activation_2[0][0]']
#  spose)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 32)  128         ['conv2d_transpose_2[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 28, 28, 32)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 28, 28, 1)   801         ['activation_3[0][0]']
#  spose)
#
#  activation_4 (Activation)      (None, 28, 28, 1)    0           ['conv2d_transpose_3[0][0]']
#
# ==================================================================================================
# Total params: 1,364,225
# Trainable params: 1,363,521
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
D.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  dense (Dense)                  (None, 784)          8624        ['input_2[0][0]']
#
#  input_3 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  reshape (Reshape)              (None, 28, 28, 1)    0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 2)    0           ['input_3[0][0]',
#                                                                   'reshape[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 28, 28, 2)    0           ['concatenate[0][0]']
#
#  conv2d (Conv2D)                (None, 14, 14, 32)   1632        ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 14, 14, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     51264       ['leaky_re_lu_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 7, 7, 64)     0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 4, 4, 128)    204928      ['leaky_re_lu_2[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 4, 4, 128)    0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 4, 4, 256)    819456      ['leaky_re_lu_3[0][0]']
#
#  flatten (Flatten)              (None, 4096)         0           ['conv2d_3[0][0]']
#
#  dense_1 (Dense)                (None, 1)            4097        ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1,090,001
# Trainable params: 0
# Non-trainable params: 1,090,001
# __________________________________________________________________________________________________

# %%
A.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100)]        0           []
#
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  generator (Functional)         (None, 28, 28, 1)    1364225     ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  model_1 (Functional)           (None, 1)            1090001     ['generator[0][0]',
#                                                                   'input_2[0][0]']
#
# ==================================================================================================
# Total params: 2,454,226
# Trainable params: 1,363,521
# Non-trainable params: 1,090,705
# __________________________________________________________________________________________________

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
train_gan(G, D, A)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 22s 2us/step
# 2/2 [==============================] - 1s 163ms/step
# 0 [Discriminator loss: 0.698413, acc: 0.250000, Adversarial loss: 0.976439, acc: 0.000000]
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 202ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 214ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 206ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 201ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 189ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 203ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 121ms/step
# 100 [Discriminator loss: 0.000326, acc: 1.000000, Adversarial loss: 0.000019, acc: 1.000000]
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 202ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 189ms/step
# 2/2 [==============================] - 0s 206ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 204ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 89ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 118ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 197ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 202ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 207ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 142ms/step
# 200 [Discriminator loss: 0.000729, acc: 1.000000, Adversarial loss: 0.000109, acc: 1.000000]
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 209ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 128ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 197ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 203ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 100ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 196ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 138ms/step
# 300 [Discriminator loss: 0.013362, acc: 1.000000, Adversarial loss: 0.001637, acc: 1.000000]
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 207ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 204ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 189ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 197ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 99ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 204ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 197ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 207ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 191ms/step
# 400 [Discriminator loss: 0.068547, acc: 1.000000, Adversarial loss: 1.626936, acc: 0.000000]
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 116ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 197ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 105ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 107ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 121ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 205ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 82ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 500ms/step
# 2/2 [==============================] - 0s 122ms/step
# 500 [Discriminator loss: 0.029422, acc: 0.992188, Adversarial loss: 0.106376, acc: 1.000000]
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 201ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 101ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 114ms/step
# 600 [Discriminator loss: 0.597612, acc: 0.765625, Adversarial loss: 4.060557, acc: 0.000000]
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 126ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 196ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 137ms/step
# 700 [Discriminator loss: 0.019294, acc: 0.992188, Adversarial loss: 0.000399, acc: 1.000000]
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 95ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 227ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 212ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 1s 234ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 226ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 132ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 104ms/step
# 2/2 [==============================] - 1s 235ms/step
# 2/2 [==============================] - 0s 157ms/step
# 800 [Discriminator loss: 0.381049, acc: 0.820312, Adversarial loss: 1.539606, acc: 0.109375]
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 274ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 1s 209ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 1s 278ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 159ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 1s 181ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 94ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 1s 181ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 1s 156ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 1s 220ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 129ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 111ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 1s 232ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 120ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 138ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 153ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 150ms/step
# 900 [Discriminator loss: 0.618830, acc: 0.656250, Adversarial loss: 1.889999, acc: 0.046875]
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 158ms/step
# 2/2 [==============================] - 0s 155ms/step
# 2/2 [==============================] - 0s 154ms/step
# 2/2 [==============================] - 0s 122ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 113ms/step
# 2/2 [==============================] - 0s 124ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 144ms/step
# 2/2 [==============================] - 0s 152ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 130ms/step
# 2/2 [==============================] - 0s 112ms/step
# 2/2 [==============================] - 0s 143ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 1s 210ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 131ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 148ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 135ms/step
# 2/2 [==============================] - 0s 156ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 1s 182ms/step
# 2/2 [==============================] - 0s 142ms/step
# 2/2 [==============================] - 0s 145ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 150ms/step
# 2/2 [==============================] - 0s 151ms/step
# 2/2 [==============================] - 0s 139ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 115ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 157ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 134ms/step
# 2/2 [==============================] - 0s 141ms/step
# 2/2 [==============================] - 0s 140ms/step
# 2/2 [==============================] - 0s 117ms/step
# 2/2 [==============================] - 0s 137ms/step
# 2/2 [==============================] - 0s 123ms/step
# 2/2 [==============================] - 0s 133ms/step
# 2/2 [==============================] - 0s 161ms/step
# 2/2 [==============================] - 0s 127ms/step
# 2/2 [==============================] - 0s 136ms/step
# 2/2 [==============================] - 1s 191ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 108ms/step
# 2/2 [==============================] - 0s 131ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11296\3917587836.py in <cell line: 1>()
# ----> 1 train_gan(G, D, A)
#
# ~\AppData\Local\Temp\ipykernel_11296\2817279234.py in train_gan(generator, discriminator, adversarial, noise_size)
#      60
#      61         #3. Train - Pls note Discrimator is not getting trained here
# ---> 62         a_loss, a_acc = adversarial.train_on_batch([X_noise, X_fake_labels], y)
#      63
#      64         if i % 100 == 0:
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    2379             )
#    2380             self.train_function = self.make_train_function()
# -> 2381             logs = self.train_function(iterator)
#    2382
#    2383         logs = tf_utils.sync_to_numpy_or_python_type(logs)
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2494       (graph_function,
#    2495        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496     return graph_function._call_flat(
#    2497         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2498
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1860         and executing_eagerly):
#    1861       # No tape is watching; skip to running the function.
# -> 1862       return self._build_call_outputs(self._inference_function.call(
#    1863           ctx, args, cancellation_manager=cancellation_manager))
#    1864     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\Anaconda3\envs\kedro_env\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def test_generator(generator, label):
    
    test_noise_input = np.random.uniform(-1.0,1.0, size=[16, 100])
    test_fake_labels = np.eye(10)[np.repeat(label, 16)]
    fake_images = generator.predict([test_noise_input, test_fake_labels])
    plot_images(fake_images, 0)

# %%
test_generator(G, 7)
